# %% [markdown]
# <a href="https://www.kaggle.com/code/shubhamgupta012/subword-tokenization-nlp?scriptVersionId=130216443" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import tensorflow as tf

from tensorflow.keras.preprocessing.sequence import pad_sequences
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# !wget --no-check-certificate \
    https://drive.google.com/uc?id=13ySLC_ue6Umt9RJYSeM2t-V0kCv-4C-P \
    -O /tmp/sentiment.csv
# Out:
# --2023-05-19 17:11:54--  https://drive.google.com/uc?id=13ySLC_ue6Umt9RJYSeM2t-V0kCv-4C-P
# Resolving drive.google.com (drive.google.com)... 74.125.204.101, 74.125.204.113, 74.125.204.138, ...
# Connecting to drive.google.com (drive.google.com)|74.125.204.101|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-08-ak-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/f5lbvfa468ut8ide7ir29uavf7nkv0v6/1684516275000/11118900490791463723/*/13ySLC_ue6Umt9RJYSeM2t-V0kCv-4C-P?uuid=8614fdb2-7a7d-476e-9737-037d9991ba13 [following]
# Warning: wildcards not supported in HTTP.
# --2023-05-19 17:11:54--  https://doc-08-ak-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/f5lbvfa468ut8ide7ir29uavf7nkv0v6/1684516275000/11118900490791463723/*/13ySLC_ue6Umt9RJYSeM2t-V0kCv-4C-P?uuid=8614fdb2-7a7d-476e-9737-037d9991ba13
# Resolving doc-08-ak-docs.googleusercontent.com (doc-08-ak-docs.googleusercontent.com)... 74.125.23.132, 2404:6800:4008:c02::84
# Connecting to doc-08-ak-docs.googleusercontent.com (doc-08-ak-docs.googleusercontent.com)|74.125.23.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 127831 (125K) [text/csv]
# Saving to: ‘/tmp/sentiment.csv’
#
# /tmp/sentiment.csv  100%[===================>] 124.83K  --.-KB/s    in 0.002s
#
# 2023-05-19 17:11:55 (63.1 MB/s) - ‘/tmp/sentiment.csv’ saved [127831/127831]

# %%
import pandas as pd

dataset = pd.read_csv('/tmp/sentiment.csv')

# Just extract out sentences and labels first - we will create subwords here
sentences = dataset['text'].tolist()
labels = dataset['sentiment'].tolist()

# %% [markdown]
# ## Create a subwords dataset
#
# We can use the existing Amazon and Yelp reviews dataset with `tensorflow_datasets`'s `SubwordTextEncoder` functionality. `SubwordTextEncoder.build_from_corpus()` will create a tokenizer for us. You could also use this functionality to get subwords from a much larger corpus of text as well, but we'll just use our existing dataset here.
#
# The Amazon and Yelp dataset we are using isn't super large, so we'll create a subword `vocab_size` of only the 1,000 most common words, as well as cutting off each subword to be at most 5 characters.
#
# Check out the related documentation [here](https://www.tensorflow.org/datasets/api_docs/python/tfds/features/text/SubwordTextEncoder#build_from_corpus).

# %%
import tensorflow_datasets as tfds

vocab_size = 1000
tokenizer = tfds.deprecated.text.SubwordTextEncoder.build_from_corpus(sentences, vocab_size, max_subword_length=5)

# %%
# Check that the tokenizer works appropriately
num = 5
print(sentences[num])
encoded = tokenizer.encode(sentences[num])
print(encoded)
# Separately print out each subword, decoded
for i in encoded:
  print(tokenizer.decode([i]))
# Out:
# I have to jiggle the plug to get it to line up right to get decent volume.
# [4, 31, 6, 849, 162, 450, 12, 1, 600, 438, 775, 6, 175, 14, 6, 55, 213, 159, 474, 775, 6, 175, 614, 380, 295, 148, 72, 789]
# I
# have
# to
# j
# ig
# gl
# e
# the
# pl
# ug
#
# to
# get
# it
# to
# li
# ne
# up
# right
#
# to
# get
# dec
# ent
# vo
# lu
# me
# .

# %% [markdown]
# ## Replace sentence data with encoded subwords
#
# Now, we'll re-create the dataset to be used for training by actually encoding each of the individual sentences. This is equivalent to `text_to_sequences` with the `Tokenizer` we used in earlier exercises.

# %%
for i, sentence in enumerate(sentences):
  sentences[i] = tokenizer.encode(sentence)

# %%
# Check the sentences are appropriately replaced
print(sentences[1])
# Out:
# [625, 677, 626, 274, 380, 633, 148, 844, 789]

# %% [markdown]
# ## Final pre-processing
#
# Before training, we still need to pad the sequences, as well as split into training and test sets.

# %%
import numpy as np

max_length = 50
trunc_type='post'
padding_type='post'

# Pad all sentences
sentences_padded = pad_sequences(sentences, maxlen=max_length, 
                                 padding=padding_type, truncating=trunc_type)

# Separate out the sentences and labels into training and test sets
training_size = int(len(sentences) * 0.8)

training_sentences = sentences_padded[0:training_size]
testing_sentences = sentences_padded[training_size:]
training_labels = labels[0:training_size]
testing_labels = labels[training_size:]

# Make labels into numpy arrays for use with the network later
training_labels_final = np.array(training_labels)
testing_labels_final = np.array(testing_labels)

# %% [markdown]
# ## Train a Sentiment Model

# %%
embedding_dim = 16
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(6, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 50, 16)            16000
#
#  global_average_pooling1d (G  (None, 16)               0
#  lobalAveragePooling1D)
#
#  dense (Dense)               (None, 6)                 102
#
#  dense_1 (Dense)             (None, 1)                 7
#
# =================================================================
# Total params: 16,109
# Trainable params: 16,109
# Non-trainable params: 0
# _________________________________________________________________

# %%
num_epochs = 30
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
history = model.fit(training_sentences, training_labels_final, epochs=num_epochs, 
                    validation_data=(testing_sentences, testing_labels_final))
# Out:
# Epoch 1/30
# 50/50 [==============================] - 1s 7ms/step - loss: 0.6920 - accuracy: 0.5242 - val_loss: 0.6958 - val_accuracy: 0.4110
# Epoch 2/30
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6899 - accuracy: 0.5223 - val_loss: 0.6984 - val_accuracy: 0.4110
# Epoch 3/30
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6868 - accuracy: 0.5348 - val_loss: 0.6969 - val_accuracy: 0.4461
# Epoch 4/30
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6811 - accuracy: 0.5606 - val_loss: 0.6904 - val_accuracy: 0.5088
# Epoch 5/30
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6698 - accuracy: 0.6277 - val_loss: 0.6883 - val_accuracy: 0.5063
# Epoch 6/30
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6496 - accuracy: 0.6616 - val_loss: 0.6608 - val_accuracy: 0.6541
# Epoch 7/30
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6207 - accuracy: 0.7244 - val_loss: 0.6438 - val_accuracy: 0.6541
# Epoch 8/30
# 50/50 [==============================] - 0s 3ms/step - loss: 0.5852 - accuracy: 0.7778 - val_loss: 0.6124 - val_accuracy: 0.7168
# Epoch 9/30
# 50/50 [==============================] - 0s 3ms/step - loss: 0.5451 - accuracy: 0.8029 - val_loss: 0.5837 - val_accuracy: 0.7669
# Epoch 10/30
# 50/50 [==============================] - 0s 3ms/step - loss: 0.5038 - accuracy: 0.8311 - val_loss: 0.5737 - val_accuracy: 0.7218
# Epoch 11/30
# 50/50 [==============================] - 0s 3ms/step - loss: 0.4649 - accuracy: 0.8399 - val_loss: 0.5358 - val_accuracy: 0.7694
# Epoch 12/30
# 50/50 [==============================] - 0s 3ms/step - loss: 0.4293 - accuracy: 0.8575 - val_loss: 0.5310 - val_accuracy: 0.7444
# Epoch 13/30
# 50/50 [==============================] - 0s 3ms/step - loss: 0.4002 - accuracy: 0.8644 - val_loss: 0.5239 - val_accuracy: 0.7419
# Epoch 14/30
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3749 - accuracy: 0.8638 - val_loss: 0.5210 - val_accuracy: 0.7444
# Epoch 15/30
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3495 - accuracy: 0.8814 - val_loss: 0.5060 - val_accuracy: 0.7519
# Epoch 16/30
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3293 - accuracy: 0.8814 - val_loss: 0.5049 - val_accuracy: 0.7469
# Epoch 17/30
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3103 - accuracy: 0.8889 - val_loss: 0.4986 - val_accuracy: 0.7594
# Epoch 18/30
# 50/50 [==============================] - 0s 4ms/step - loss: 0.2973 - accuracy: 0.8927 - val_loss: 0.4919 - val_accuracy: 0.7669
# Epoch 19/30
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2802 - accuracy: 0.9014 - val_loss: 0.5013 - val_accuracy: 0.7494
# Epoch 20/30
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2669 - accuracy: 0.9083 - val_loss: 0.5119 - val_accuracy: 0.7569
# Epoch 21/30
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2560 - accuracy: 0.9096 - val_loss: 0.5114 - val_accuracy: 0.7619
# Epoch 22/30
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2449 - accuracy: 0.9196 - val_loss: 0.5041 - val_accuracy: 0.7519
# Epoch 23/30
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2370 - accuracy: 0.9184 - val_loss: 0.5362 - val_accuracy: 0.7519
# Epoch 24/30
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2256 - accuracy: 0.9234 - val_loss: 0.5331 - val_accuracy: 0.7544
# Epoch 25/30
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2170 - accuracy: 0.9272 - val_loss: 0.5639 - val_accuracy: 0.7469
# Epoch 26/30
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2111 - accuracy: 0.9291 - val_loss: 0.5488 - val_accuracy: 0.7544
# Epoch 27/30
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2022 - accuracy: 0.9322 - val_loss: 0.5597 - val_accuracy: 0.7494
# Epoch 28/30
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1956 - accuracy: 0.9366 - val_loss: 0.5422 - val_accuracy: 0.7619
# Epoch 29/30
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1913 - accuracy: 0.9385 - val_loss: 0.5555 - val_accuracy: 0.7569
# Epoch 30/30
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1832 - accuracy: 0.9422 - val_loss: 0.5640 - val_accuracy: 0.7544

# %%
import matplotlib.pyplot as plt


def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()
  
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

# %%
# First get the weights of the embedding layer
e = model.layers[0]
weights = e.get_weights()[0]
print(weights.shape) # shape: (vocab_size, embedding_dim)
# Out:
# (1000, 16)

# %%
import io

# Write out the embedding vectors and metadata
out_v = io.open('vecs.tsv', 'w', encoding='utf-8')
out_m = io.open('meta.tsv', 'w', encoding='utf-8')
for word_num in range(0, vocab_size - 1):
  word = tokenizer.decode([word_num])
  embeddings = weights[word_num]
  out_m.write(word + "\n")
  out_v.write('\t'.join([str(x) for x in embeddings]) + "\n")
out_v.close()
out_m.close()

# %%
# Download the files
try:
  from google.colab import files
except ImportError:
  pass
else:
  files.download('vecs.tsv')
  files.download('meta.tsv')
